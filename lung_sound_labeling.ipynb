# %% [markdown]
# ##Import all modules

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import keras
from keras.layers import Activation, Dense, Dropout, Conv2D, Flatten, MaxPooling2D
from keras.models import Sequential
import librosa
import librosa.display
import numpy as np
import pandas as pd
import random
import matplotlib.pyplot as plt
import os
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
path= os.getcwd()
file_name="MyDrive"
new_path= os.path.join(path,file_name)

# %%
os.listdir()
# Out:
# ['Colab Notebooks',
#  'content',
#  'boneFracture',
#  'FaceDetection.ipynb',
#  'new',
#  'New folder (3)',
#  '4_5963250851395933297.pdf',
#  'Recommendation System .ipynb',
#  'pneumonia-detection.ipynb',
#  'pneumonia dataset.zip',
#  'chest_xray',
#  'cnn-on-chest-x-ray-images.ipynb',
#  'Sound Sensor Library for Proteus',
#  'Audio Files',
#  'Data annotation.xlsx']

# %%
path= os.getcwd()
file_name="Audio Files"
new_path= os.path.join(path,file_name)
os.chdir(new_path)

# %%
os.listdir()[1]
# Out:
# 'BP34_heart failure,Crep,P R M,78,F.wav'

# %%
import IPython.display as ipd
ipd.Audio(os.listdir()[24])
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
y, sr=librosa.load(os.listdir()[24], duration=2.97)
ps= librosa.feature.melspectrogram(y=y,sr=sr)
ps.shape
# Out:
# (128, 128)

# %%
librosa.display.specshow(ps,y_axis='mel', x_axis='time')

# %%
x=librosa.stft(y)
xdb=librosa.amplitude_to_db(abs(x))
plt.figure(figsize=(14,5))
librosa.display.specshow(xdb, sr=sr, x_axis='time', y_axis='hz')
